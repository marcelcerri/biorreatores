# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelcerri/biorreatores/blob/main/Algoritmo_gen%C3%A9tico_aula_PFI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Baseado no site - https://pablormier.github.io/2017/09/05/a-tutorial-on-differential-evolution-with-python/#

# %% [markdown]
# Vídeo Explicativo de algoritmo genético - https://www.youtube.com/watch?v=xtHMSJLnKsE

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution

# %%
# Criando os pontos experimentais
x = np.linspace(0,10,500)
y = np.cos(x) + np.random.normal(0, 0.2, 500)
plt.scatter(x,y)
plt.plot(x, np.cos(x), "-r", label = "cos(x)")
plt.legend()

# %%
def model(x, w):
  return w[0] + w[1]*x + w[2]*x**2 + w[3]*x**3 + w[4]*x**4 + w[5]*x**5

# %%
def objetiva(w):
  y_pred = model(x,w)
  residuo = np.sqrt(sum((y - y_pred)**2)/len(y))
  return residuo

# %%
plt.plot(x, model(x, [1.0, -0.01, 2, -0.1, 0.1, -0.01]))
plt.show()

# %%
resultado = differential_evolution(objetiva, [(-5, 5)]*6, maxiter=2000, popsize=30)
parametros = resultado.x
print(resultado.nit)
# Out:
# 194

# %%
plt.scatter(x, y)
plt.plot(x, np.cos(x), "-r", label = "cos(x)")
plt.plot(x, model(x, parametros), "-k", label="resultado")
plt.legend
plt.show()
print(parametros)
# Out:
# [ 0.8700657   0.75900346 -1.55687554  0.55043172 -0.06942594  0.00290615]
